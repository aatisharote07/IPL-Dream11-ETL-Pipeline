# %%
# !pip install mysql.connector
import mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 28.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp312-cp312-linux_x86_64.whl size=247950 sha256=88dd29d840965f0d1886d319d8665595da6ca736f6b305847bce4d17ba635a63
#   Stored in directory: /root/.cache/pip/wheels/03/17/fa/d7604c72dd3dd6d3eb3d249abf36cc532c9a9b4354b8f1bc4f
# Successfully built mysql.connector
# ...

# %%
conn = mysql.connector.connect(host='database-1.cbmukie6y91x.ap-southeast-2.rds.amazonaws.com',user='admin',password='9THBmVTC6DwATQ3')

# %%
# !pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 2.7 MB/s eta 0:00:00
# ...

# %%
import pymysql
from sqlalchemy import create_engine

# %%
import pandas as pd
df = pd.read_csv(r"/IPL.csv")
# Out:
# /tmp/ipython-input-3556460391.py:2: DtypeWarning: Columns (20,28,29,30,31,32,43,46,47,48,51,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"/IPL.csv")

# %%
mycursor = conn.cursor()

# %%
mycursor.execute("CREATE DATABASE dream11")
conn.commit()

# %%
engine = create_engine("mysql+pymysql://admin:9THBmVTC6DwATQ3@database-1.cbmukie6y91x.ap-southeast-2.rds.amazonaws.com/dream11")
# {root}:{password}@{url}/{database}
df.to_sql('ipl', con = engine)
# Out:
# 183982

# %%
import mysql.connector
conn = mysql.connector.connect(host='database-1.cbmukie6y91x.ap-southeast-2.rds.amazonaws.com',user='admin',password='9THBmVTC6DwATQ3',database="dream11")

# %%
mycursor = conn.cursor()

# %%
import pandas as pd

# %%
pd.read_sql_query("SELECT * FROM ipl",conn,index_col = "index")
# Out:
# /tmp/ipython-input-1205841383.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM ipl",conn,index_col = "index")
#         Unnamed: 0  match_id        date match_type             event_name  \
# index
# 0           131970    335982  2008-04-18        T20  Indian Premier League
# 1           131971    335982  2008-04-18        T20  Indian Premier League
# 2           131972    335982  2008-04-18        T20  Indian Premier League
# 3           131973    335982  2008-04-18        T20  Indian Premier League
# 4           131974    335982  2008-04-18        T20  Indian Premier League
# ...            ...       ...         ...        ...                    ...
# 183977       47271   1216511  2020-10-06        T20  Indian Premier League
# ...
